# %%
from __future__ import print_function
import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
import tensorflow

# %%
batch_size = 128
num_classes = 10
epoch = 30

# %%
img_rows, img_cols = 28,28
(x_train,y_train),(x_test,y_test) = mnist.load_data()
if K.image_data_format() == 'channels_first':
  x_train = x_train.reshape(x_train.shape[0],1,img_rows,img_cols)
  x_test = x_test.reshape(x_test.shape[0],1,img_rows,img_cols)
  input_shape = (1,img_rows,img_cols)
else: 
  x_train = x_train.reshape(x_train.shape[0],img_rows,img_cols,1)
  x_test = x_test.reshape(x_test.shape[0],img_rows,img_cols,1)
  input_shape = (img_rows,img_cols,1)

# %%
x_train=x_train.astype('float32')/255
x_test=x_test.astype('float32')/255

y_train = tensorflow.keras.utils.to_categorical(y_train,num_classes)
y_test = tensorflow.keras.utils.to_categorical(y_test,num_classes)

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3,3),
                 activation='relu',
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))

# %%
model.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=tensorflow.keras.optimizers.Adadelta(),
              metrics=['accuracy'])

# %%
model.fit(x_train,y_train,
          batch_size=batch_size,
          epochs = epoch,
          verbose=1)
# Out:
# Epoch 1/30
# 469/469 [==============================] - 2s 4ms/step - loss: 2.2917 - accuracy: 0.1272
# Epoch 2/30
# 469/469 [==============================] - 2s 4ms/step - loss: 2.2549 - accuracy: 0.1907
# Epoch 3/30
# 469/469 [==============================] - 2s 4ms/step - loss: 2.2182 - accuracy: 0.2619
# Epoch 4/30
# 469/469 [==============================] - 2s 4ms/step - loss: 2.1788 - accuracy: 0.3341
# Epoch 5/30
# 469/469 [==============================] - 2s 4ms/step - loss: 2.1336 - accuracy: 0.3968
# Epoch 6/30
# 469/469 [==============================] - 2s 4ms/step - loss: 2.0842 - accuracy: 0.4499
# Epoch 7/30
# 469/469 [==============================] - 2s 4ms/step - loss: 2.0281 - accuracy: 0.5009
# Epoch 8/30
# 469/469 [==============================] - 2s 4ms/step - loss: 1.9691 - accuracy: 0.5318
# Epoch 9/30
# 469/469 [==============================] - 2s 4ms/step - loss: 1.9047 - accuracy: 0.5613
# Epoch 10/30
# 469/469 [==============================] - 2s 4ms/step - loss: 1.8365 - accuracy: 0.5858
# Epoch 11/30
# 469/469 [==============================] - 2s 4ms/step - loss: 1.7689 - accuracy: 0.5998
# Epoch 12/30
# 469/469 [==============================] - 2s 4ms/step - loss: 1.6958 - accuracy: 0.6176
# Epoch 13/30
# 469/469 [==============================] - 2s 4ms/step - loss: 1.6245 - accuracy: 0.6335
# Epoch 14/30
# 469/469 [==============================] - 2s 4ms/step - loss: 1.5568 - accuracy: 0.6439
# Epoch 15/30
# 469/469 [==============================] - 2s 4ms/step - loss: 1.4890 - accuracy: 0.6532
# Epoch 16/30
# 469/469 [==============================] - 2s 4ms/step - loss: 1.4236 - accuracy: 0.6655
# Epoch 17/30
# 469/469 [==============================] - 2s 4ms/step - loss: 1.3648 - accuracy: 0.6738
# Epoch 18/30
# 469/469 [==============================] - 2s 4ms/step - loss: 1.3082 - accuracy: 0.6836
# Epoch 19/30
# 469/469 [==============================] - 2s 4ms/step - loss: 1.2540 - accuracy: 0.6936
# Epoch 20/30
# 469/469 [==============================] - 2s 4ms/step - loss: 1.2013 - accuracy: 0.7019
# Epoch 21/30
# 469/469 [==============================] - 2s 4ms/step - loss: 1.1569 - accuracy: 0.7079
# Epoch 22/30
# 469/469 [==============================] - 2s 4ms/step - loss: 1.1133 - accuracy: 0.7155
# Epoch 23/30
# 469/469 [==============================] - 2s 4ms/step - loss: 1.0793 - accuracy: 0.7176
# Epoch 24/30
# 469/469 [==============================] - 2s 4ms/step - loss: 1.0413 - accuracy: 0.7253
# Epoch 25/30
# 469/469 [==============================] - 2s 4ms/step - loss: 1.0065 - accuracy: 0.7340
# Epoch 26/30
# 469/469 [==============================] - 2s 4ms/step - loss: 0.9828 - accuracy: 0.7363
# Epoch 27/30
# 469/469 [==============================] - 2s 4ms/step - loss: 0.9488 - accuracy: 0.7435
# Epoch 28/30
# 469/469 [==============================] - 2s 4ms/step - loss: 0.9252 - accuracy: 0.7475
# Epoch 29/30
# 469/469 [==============================] - 2s 4ms/step - loss: 0.8994 - accuracy: 0.7548
# Epoch 30/30
# 469/469 [==============================] - 2s 4ms/step - loss: 0.8807 - accuracy: 0.7574

# %%
score=model.evaluate(x_test,y_test,verbose=0)
print('Test loss : ',score[0])
print('Test acc : ',score[1])
# Out:
# Test loss :  0.6933650374412537
# Test acc :  0.8546000123023987

# %%
model2 = Sequential()
model2.add(Conv2D(32, kernel_size=(3,3),
                 activation='relu',
                 input_shape=input_shape))
model2.add(Conv2D(32,(3,3),activation='relu'))
model2.add(MaxPooling2D(pool_size=(2,2)))
model2.add(Dropout(0.25))
model2.add(Flatten())
model2.add(Dense(128, activation='relu'))
model2.add(Dropout(0.5))
model2.add(Dense(num_classes, activation='softmax'))

# %%
model2.compile(loss=keras.losses.categorical_crossentropy,
              optimizer=tensorflow.keras.optimizers.Adadelta(),
              metrics=['accuracy'])
model2.fit(x_train,y_train,
          batch_size=batch_size,
          epochs = epoch,
          verbose=1)
score=model2.evaluate(x_test,y_test,verbose=0)
print('Test loss : ',score[0])
print('Test acc : ',score[1])
# Out:
# Epoch 1/30
# 469/469 [==============================] - 3s 6ms/step - loss: 2.2896 - accuracy: 0.1170
# Epoch 2/30
# 469/469 [==============================] - 3s 6ms/step - loss: 2.2516 - accuracy: 0.1708
# Epoch 3/30
# 469/469 [==============================] - 3s 6ms/step - loss: 2.2102 - accuracy: 0.2234
# Epoch 4/30
# 469/469 [==============================] - 3s 6ms/step - loss: 2.1574 - accuracy: 0.2812
# Epoch 5/30
# 469/469 [==============================] - 3s 6ms/step - loss: 2.0930 - accuracy: 0.3364
# Epoch 6/30
# 469/469 [==============================] - 3s 6ms/step - loss: 2.0109 - accuracy: 0.3950
# Epoch 7/30
# 469/469 [==============================] - 3s 6ms/step - loss: 1.9161 - accuracy: 0.4445
# Epoch 8/30
# 469/469 [==============================] - 3s 6ms/step - loss: 1.8019 - accuracy: 0.4954
# Epoch 9/30
# 469/469 [==============================] - 3s 6ms/step - loss: 1.6783 - accuracy: 0.5339
# Epoch 10/30
# 469/469 [==============================] - 3s 6ms/step - loss: 1.5563 - accuracy: 0.5679
# Epoch 11/30
# 469/469 [==============================] - 3s 6ms/step - loss: 1.4423 - accuracy: 0.5936
# Epoch 12/30
# 469/469 [==============================] - 3s 6ms/step - loss: 1.3454 - accuracy: 0.6125
# Epoch 13/30
# 469/469 [==============================] - 3s 6ms/step - loss: 1.2551 - accuracy: 0.6321
# Epoch 14/30
# 469/469 [==============================] - 3s 6ms/step - loss: 1.1843 - accuracy: 0.6492
# Epoch 15/30
# 469/469 [==============================] - 3s 6ms/step - loss: 1.1215 - accuracy: 0.6606
# Epoch 16/30
# 469/469 [==============================] - 3s 6ms/step - loss: 1.0679 - accuracy: 0.6743
# Epoch 17/30
# 469/469 [==============================] - 3s 6ms/step - loss: 1.0213 - accuracy: 0.6848
# Epoch 18/30
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9818 - accuracy: 0.6945
# Epoch 19/30
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9466 - accuracy: 0.7048
# Epoch 20/30
# 469/469 [==============================] - 3s 6ms/step - loss: 0.9093 - accuracy: 0.7167
# Epoch 21/30
# 469/469 [==============================] - 3s 6ms/step - loss: 0.8826 - accuracy: 0.7240
# Epoch 22/30
# 469/469 [==============================] - 3s 6ms/step - loss: 0.8590 - accuracy: 0.7310
# Epoch 23/30
# 469/469 [==============================] - 3s 6ms/step - loss: 0.8364 - accuracy: 0.7368
# Epoch 24/30
# 469/469 [==============================] - 3s 6ms/step - loss: 0.8102 - accuracy: 0.7437
# Epoch 25/30
# 469/469 [==============================] - 3s 6ms/step - loss: 0.7916 - accuracy: 0.7506
# Epoch 26/30
# 469/469 [==============================] - 3s 6ms/step - loss: 0.7748 - accuracy: 0.7550
# Epoch 27/30
# 469/469 [==============================] - 3s 6ms/step - loss: 0.7566 - accuracy: 0.7607
# Epoch 28/30
# 469/469 [==============================] - 3s 6ms/step - loss: 0.7426 - accuracy: 0.7658
# Epoch 29/30
# 469/469 [==============================] - 3s 6ms/step - loss: 0.7252 - accuracy: 0.7711
# Epoch 30/30
# 469/469 [==============================] - 3s 6ms/step - loss: 0.7167 - accuracy: 0.7737
# Test loss :  0.47225502133369446
# Test acc :  0.8747000098228455
